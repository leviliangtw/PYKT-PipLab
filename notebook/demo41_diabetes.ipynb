# %%
import tensorflow
import keras

print(f'tensorflow current version={tensorflow.__version__}')
print(f'keras current version={keras.__version__}')
# Out:
# tensorflow current version=2.0.0
# keras current version=2.3.1
# Using TensorFlow backend.

# %%
import numpy
import os
from keras.layers import Dense
from keras import Sequential
print(os.getcwd())
# Out:
# /home/leviliang/PycharmProjects/PipLab/notebook

# %%
# load data
dataset1 = numpy.loadtxt('../data/diabetes.csv', delimiter=',', skiprows=1)
print(type(dataset1), dataset1.shape)
# Out:
# <class 'numpy.ndarray'> (768, 9)

# %%
inputList = dataset1[:, :8]
resultList = dataset1[:, 8]
print("feature size: ", inputList.shape)
print("result size: ", resultList.shape)
# Out:
# feature size:  (768, 8)
# result size:  (768,)

# %%
from sklearn.model_selection import train_test_split 
feature_train, feature_test, label_train, label_test = train_test_split(inputList, resultList, 
                                                                        test_size=0.2, 
                                                                        random_state=3579)
print(feature_train[:5, :])
# Out:
# [[  4.    156.     75.      0.      0.     48.3     0.238  32.   ]
#  [  9.    102.     76.     37.      0.     32.9     0.665  46.   ]
#  [  7.    103.     66.     32.      0.     39.1     0.344  31.   ]
#  [  3.    132.     80.      0.      0.     34.4     0.402  44.   ]
#  [  3.     78.     50.     32.     88.     31.      0.248  26.   ]]

# %%
model = Sequential()
model.add(Dense(50, input_dim=8, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
history = model.fit(inputList, resultList, epochs=200, batch_size=5, validation_split=0.1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 50)                450
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...
# Total params: 3,051
# Trainable params: 3,051
# Non-trainable params: 0
# _________________________________________________________________
# Train on 691 samples, validate on 77 samples
# Epoch 1/200
# 691/691 [==============================] - 0s 524us/step - loss: 1.1679 - accuracy: 0.6208 - val_loss: 1.2597 - val_accuracy: 0.5325
# Epoch 2/200
# 691/691 [==============================] - 0s 252us/step - loss: 1.0884 - accuracy: 0.6093 - val_loss: 1.0517 - val_accuracy: 0.5325
# Epoch 3/200
# ...

# %%
scores = model.evaluate(inputList, resultList)
print("metrics name: ", model.metrics_names)
print("%s: %.3f%%" % (model.metrics_names[1],
                         scores[1] * 100))
print("%s: %.3f" % (model.metrics_names[0],
                       scores[0]))
# Out:
# 768/768 [==============================] - 0s 16us/step
# metrics name:  ['loss', 'accuracy']
# accuracy: 85.286%
# loss: 0.336

# %%
type(scores)
# Out:
# list

# %%
for s in scores:
    print(s)
# Out:
# 0.3359066291401784
# 0.8528645634651184

# %%
type(model.metrics_names)
# Out:
# list

# %%
for s in model.metrics_names:
    print(s)
# Out:
# loss
# accuracy

# %%
for s, m in zip(scores, model.metrics_names):
    print(f'{m}:{s}')
# Out:
# loss:0.3359066291401784
# accuracy:0.8528645634651184

# %%
type(history)
# Out:
# keras.callbacks.callbacks.History

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.legend(['accuracy', 'loss'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_loss'])
plt.plot(history.history['val_accuracy'])
plt.legend(['val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
